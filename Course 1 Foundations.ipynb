# %%
Course 1 Foundations: Data, Data, Everywhere

- Data analysis:
    - collection, transformation, and organization of data in order to draw conclusions, make predictions, and drive infromed decision-making
- Data Analyst:
    - Someone who collects, transforms and organizes data in order to help make informed decisions

- Six steps of the data analysis process
    - Ask:
        - Data Analyst ask effective questions and collaborate with leaders and managers who were interested in the outcome of their people analysis.
    - Prepare
        - Analysts identified what data they needed to achieve the successful result
    - Process
        - Great analysts know how to respect both their data and the people who provides it.
        - Need to get their consent to participate.
        - Clean the data and make sure that its complete, correct, relevant and free of errors and outliers.
        - Need to make sure participants know their data would be collected, stored, managed, and protected.
        - It's analysts job to be collecting and using data ethically-- in order to maintain confidentiality and protect and store the data effectively.
            - Ie.
                - They restricted access to the data to a limited number of analysts.
                - They cleaned the data to make sure it was complete, correct, and relevant. Certain data was aggregated and summarized without revealing individual responses.
                - They uploaded raw data to an internal data warehouse for an additional layer of security.
    - Analyze
        - Analysts needs to know how to analyze
        - Need to know how to document what exactly they found in the trial
    - Share
        - Need to be careful when it times to share report.
        - Need to communicate the results with the right context.
        - Ie.
            - They restricted access to the data to a limited number of analysts.
            - They cleaned the data to make sure it was complete, correct, and relevant. Certain data was aggregated and summarized without revealing individual responses.
            - They uploaded raw data to an internal data warehouse for an additional layer of security.
    - Act
        - Need to know how to implement changes and take action based on the finding.
        - Do the same survey a year later to the same type of participants and compare the data.

*****Gut Instinct is an intuitive understanding of something with little or no explaining.*****

  

Data Ecosystem:

- Ecosystem is a group of elements that interact with one another.
- Various elements that interact with one another in order to produce, manage, store, organize, analyze, and share data.

  

Cloud:

- A place to keep data online rather than on a computer hard drive.

  

Data science vs Data Analyst vs Data Analytics

- Data science creating new ways modeling and understanding the unknown by using raw data (Create new questions using data while analyst find answers to existing question by creating insights from data sources).
- Data Analyst: collection, transformation, and organization of data in order to draw conclusions, make predictions, and drive informed decision-making
- Data Analytics: the science of data

  

Data Analyst Life Cycle:

1. Ask: Business Challenge/Objective/Question
2. Prepare: Data generation, collection, storage, and data management
3. Process: Data cleaning/data integrity
4. Analyze: Data exploration, visualization, and analysis
5. Share: Communicating and interpreting results 
6. Act: Putting your insights to work to solve the problem

  

EMC's data analysis life cycle:

1. Ask: Business Challenge/Objective/Question
2. Prepare: Data generation, collection, storage, and data management
3. Process: Data cleaning/data integrity
4. Analyze: Data exploration, visualization, and analysis
5. Share: Communicating and interpreting results 
6. Act: Putting your insights to work to solve the problem

  

SAS's iterative life cycle

1. Ask
2. Prepare
3. Explore
4. Model
5. Implement
6. Act
7. Evaluate

  

Project-based data analytics life cycle:

1. Identifying the problem
2. Designing data requirements
3. Pre-processing data
4. Performing data analysis
5. Visualizing data

  

Big data analytics life cycle:

1. Business case evaluation
2. Data identification
3. Data acquisition and filtering
4. Data extraction
5. Data validation and cleaning
6. Data aggregation and representation
7. Data analysis
8. Data visualization
9. Utilization of analysis results

  

Analytical Skills:

- Qualities and characteristics associated with solving problems using facts
    - 5 essential points
        1. Curiosity
        2. Understanding context
            - The condition in which something exist or happens
        3. Having a technical mindset
            - The ability to break things down into smaller steps or pieces and work with them in an orderly and logical way
        4. Data design
            - How you organize information
        5. Data strategy
            - The management of the people, processes and the tools used in data analysis

  

Analytical thinking:

- Identifying and defining a problem and then solving it by using data in an organized, step by step manner.
- 5 Key Aspects to Analytical Thinking
    1. Visualization
        - The graphical representation of information
            - Ie. Maps, graphs
    2. Strategy
        - Helps data analysts see what they want to achieve with the data and how they can get there.
        - Helps improve the quality and usefulness of the data we collect
    3. Problem-orientation
        - Use to identify, describe, and solve problems
        - Ask a lot of questions to save time
            - Surveys to detect future issues
    4. Correlation
            - Finding the relationship between two issues
            - CORRELATION DOES NOT EQUAL CAUSATION!
                - Just because two data are trending at the same direction, it does not mean that it's related.
    5. Big-picture and detail-oriented thinking
        - Big-picture is looking at the complete puzzle.
                - Don't focus on the small details, look at the whole picture and see the possibilities and opportunities.
        - Detail-oriented thinking
            - Thinking about figuring out al the aspects that will help you execute the plan.

Data Analysis Tools:

- Spreadsheets
- Data Center
- Query
- Visualization

- Data Life Cycle
    - Planning:
        - Business decides what type of data it needs and its outcome.
    - Capture:
        - Data is collected from different sources
        - Database: collect of data stored in a computer system
    - Manage:
        - How we care for data
        - how and where its stored
        - tools used to keep the data safe
    - Analyze:
        - Data is used to solve problems and help company complete its goal
    - Archive:
        - Data is kept in a storage space just in case it might be used for later
    - Destroy:
        - Do you destroy the data? If so, when and how.

  

Phases of Data Analysis
1. Ask
    - Define the problem and find the stakeholder expectations
        1. Stakeholders: people how have invested time and resources into a project and are interested in the outcome.
    - ie. Concert company wants concert goers spend less time waiting in line. The obsecle is how to solve this issue.
2. Prepare
    - Collect and store data in the upcoming analysis process.
    - You'll find out which data to use and how to use it
3. Process
4. Analyze
5. Share
6. Act

  
Module 4: Data Analytic Tools
- SQL:
	- You can use SQL to Store, Organize, and Analyze Data.
- Spreadsheets: (consider a spreadsheet when you have a smaller dataset)
	1. Cells, rows(horizontally, ordered by numbers), columns(vertically, ordered by letters)
		- Attribute: a characteristic or quality of data used to label a column in a table (Header, Column Name, Column Labels)
		- Observation: all of the attributes for something contained in a row of a data table
		
￼
			- Highlighted is called Observation of Willa Stein because we see all of the attributes in the row
		- Formula: a set of instructions that performs a specific action using the data in a spreadsheet
			- All formula starts with an equal sign 

- Data Visualization is a graphical representation of information.

Steps to plan a data visualization:
1. Explore the data for patterns
2. Plan your visuals
3. Create your visuals

The power of data in business:
- Issue: topic of subject to investigate
- Question: designed to discover information
- Problem: an obstacle or complication that needs to be worked out
- Businesss task: the question or problem data analysis answers for a business

Fairness in Data Analysis:
- Fairness: ensuring that your analysis doesn't create or reinforce bias



#dataanalysis #dataanalytics
